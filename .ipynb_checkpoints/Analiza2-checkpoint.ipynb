# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance

# %% [markdown]
# # Uvod
#
# V predhodnih študijah se je izkazalo, da ima vsak uporabnik svoj slog branja novic, zato smo se tudi odločili za personalizacijo splošnega napovednega modela. Glede na to, da želimo personalizacijo doseči v čim krajšem času smo uporabili aktivno strojno učenje. Zaradi raznolikosti uporabnikov pa ne vemo, kateri algoritem aktivnega strojnega učenja bo na posamezniku deloval najboljše. V bolj dinamičnih okoljih so v članku [Adaptive Active Learning as a Multi-armed Bandit Problem](https://www.researchgate.net/publication/264902057_Adaptive_Active_Learning_as_a_Multi-armed_Bandit_Problem) predlagali uporabo večih metod aktivnega učenja, med katerimi menjavamo s pomočjo algoritma UCB. V našem primeru smo izbrali naslednje tehnike aktivnega strojnega učenja:
#
# 1. **Razmik prepričanosti (angl. Margin of Confidence)** - ta metoda vzame dva najbolj verjetna podatka na izhodu in preveri, ali je razlika med njunima verjetnostima izhoda dovolj velika. V primeru, da je potem vprašalnika uporabniku ne zastavimo. Na tem mestu velja omeniti, da na parametre prikaza novic gledamo kot na vhod. To pomeni, da iteriramo čez vse možne prikaze novic in pogledamo za katerega izmed njih je model v določenem trenutku najbolj prepričan, da se klasificira kot "Da". Težava na katero naletimo je, da se verjetnosti v tem primeru ne seštejejo v ena. Problem lahko rešimo, da verjetnosti normaliziramo s pomočjo funkcije softmax.
# 2. **Naključna odločitev** - druga metoda, ki smo jo uporabili za odločitev, ali je uporabniku potrebno zastaviti vprašalnik, je popolnoma naključna. To pomeni, da se v nekem trenutku naključno odločimo, ali prikažemo vprašalnik. Prednost metode, ki je čisto naključna je ta, da bo raziskovala najbolj raznolik prostor podatkov.
# 3. **Naključno z upoštevanjem porazdelitve fizične aktivnosti** - glede na to, da se je pri analizi podatkov kazal velik vpliv fizične aktivnosti na končno oceno uporabnika smo se odločili na podlagi njene porazdelitve naključno zastaviti vprašalnik. Iz prve študije smo ugotovili, da uporabniki največ berejo novice, ko so pri miru in nam primanjkujejo podatki, ko se vozijo ali pa se sprehajajo. Da bi dali prednost zbiranju podatkov, ko uporabniki hodijo in se vozijo moramo takrat zastaviti največji delež vprašalnikov. To lahko dosežemo z upoštevanjem trenutne porazdelitve fizčne aktivnosti. Verjetnost, da se bo vprašalnik pojavil, ko je uporabnik pri miru mora biti najmanjša. Višja morata biti verjetnost pojavitve vprašalnika med hojo, najvišja pa med vožnjo v avtomobilu, saj imamo takih podatkov najmanj.
# 4. **Vzorečnje najmanj verjetnih izhodov (angl. Least Confidence sampling)** - pri tej metodi iščemo podatke, ko je verjetnost najboljšega prikaza novic pod odločitveno mejo modela, ki znaša 0.5. To pomeni, da bomo vprašalnik zastavali takrat, ko je verjetnost najboljšega prikaza novic, ki ga model označi kot "Da" pod vrednostjo 0.5.
#
# # Algoritem UCB
#
# Na področju spodbujevalnega strojnega učenja mora agent na podlagi interakcije z okolico sklepati, katera akcija je najboljša. Naloga agenta je torej iskanje strategije oz. zaporedja akcij brez vnaprej označenih podatkov. Iskanje učinkovite strategije menjave metod aktivnega strojnega učenja si lahko predstavljamo kot [Multi-armed bandit problem](https://en.wikipedia.org/wiki/Multi-armed_bandit). V tem primeru je agent hazarder, ki želi maksimizirat svoj izkupiček z igranjem na avtomatih. Na vsakem koraku se mora ta namreč odločiti, ali igrati na avtomatu, ki je do sedaj prinesel največji dobiček ali pa na drugem, ki bi morda lahko prinesel še višjo nagrado. V našem primeru se avtomati za srečo preslikajo v tehnike aktivnega strojnega učenja. Potrebno je uravnotežiti število izbir metode aktivnega strojnega učenja, ki se je do sedaj izkazala kot najboljša in poskuse preostalih metod, ki bi se morda lahko izkazale kot še boljše.
#
# Alogirtem UCB (Upper Confidence Bound) se je izkazal kot eden bolj učinkovitih pri reševanju omenjenega problema. Ta temelji na sledeči enačbi:
#
# <img src="https://latex.codecogs.com/svg.latex?\Large&space;A_t=argmax_a(Q_t(a) + c \sqrt\frac{ln(t)}{N_t(a)})"/>

# %% [markdown]
# * Prvi del enačbe Qt(a) predstavlja povprečno nagrado, ki jo je agent do sedaj pridobil z uporabo tehnike a in omogoča izkoriščanje uporabe do sedaj najboljše tehnike.
#
# * Drugi del enačbe pa predstavlja zgornjo mejo, ki jo agent dopušča za raziskovanje nove tehnike aktivnega strojnega učenja in je odvisna od števila do sedaj znanih poskusov na tehniki a. Večkrat kot smo izbrali določeno tehniko, manj jo želimo ponovno poskusiti, zato se tudi v imenovalcu nahaja člen Nt(a), ki predstavlja število do sedaj znanih poskusov na izbrani tehniki. Pri tem pa moramo upoštevati trenutno učinkovitost tehnike a, ki se nahaja v prvem delu enačbe (Qt(a)).
#
# Grafična predstavitev zgornje enačbe:
#
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20200126022459/Screenshot-2020-01-26-at-2.24.37-AM.png"/>

# %% [markdown]
# # Analiza zbranih podatkov druge študije
#
# V nadaljevanju bodo predstavljeni zbrani podatki druge študije, ki je trajala štiri tedne in v kateri je sodelovalo sedem ljudi. V prvem delu študije, ki je trajal dva tedna smo skušali splošni napovedni model personalizirati s pomočjo algoritma UCB. V drugem delu študije pa smo želeli z vsakodnevno menjavo personaliziranega in splošnega napovednega modela primerjati njuno učinkovitost.

# %%
## nalaganje podatkov

column_names_r = ["uID", "margin_of_conf", "random", "random_by_ua", "least_confidence", "total_reward", "all_pulls", "regret"]
rewards_df = pd.read_csv("Dataset/rewards.csv", header=None, names=column_names_r, sep=";")

column_names_p = ["uID", "margin_of_conf", "random", "random_by_ua", "least_confidence", "all_pulls"]
pulls_df = pd.read_csv("Dataset/pulls.csv", header=None, names=column_names_p, sep=";")

column_names_b = ["uID", "trial", "bandit_index", "bandit_decision", "reward", "regret", "total_reward"]
bandit_df = pd.read_csv("Dataset/bandit.csv", header=None, names=column_names_b, sep=";")

column_names_pr = ["uID", "user_activity", "env_b", "theme", "layout", "fontSize", "predictionProb", "feedback"]
pred_df = pd.read_csv("Dataset/predictions.csv", header=None, names=column_names_pr, sep=";")

column_names_ph2 = ["uID", "algo", "user_activity", "env_b", "theme", "layout", "fontSize", "feedback"]
ph2_df = pd.read_csv("Dataset/phase2.csv", header=None, names=column_names_ph2, sep=";")

# %% [markdown]
# # Analiza algoritma UCB in posameznih tehnik aktivnega strojnega učenja
#
# V spodnji tabeli je predstavljena učinkovitost algoritma UCB in posameznih tehnik aktivnega strojnega učenja na posamezniku.
#
# V prvem stolpcu tabele se nahajajo identifikatorji uporabnikov. Drugi stolpec predstavlja vektor nagrad, ki jih je pridobila posamezna tehnika aktivnega strojnega učenja, ki si sledijo v naslednjem zaporedju:
#
# 1. Razmik prepričanosti (angl. Margin of Confidence)
# 2. Naključna odločitev postavitve vprašalnika
# 3. Naključno z upoštevanjem porazdelitve fizične aktivnosti
# 4. Vzorečnje najmanj verjetnih izhodov (angl. Least Confidence sampling)
#
#
# V tretjem stolopcu vidmo kolikokrat je bila tehnika aktivnega strojnega učenja izbrana. V četrtem se nahaja skupno število poskusov algoritma UCB. V petem razberemo skupno vsoto, ki so jo dobile tehnike aktivnega strojnega učenja. V predzadnjem stolopcu se nahaja število vseh poskusov algoritma UCB, ko je naletel na kazen. V zadnjem pa lahko razberemo delež napačnih izbir algorima UCB.
#
#
# ## Analiza tabele
#
# * Pri uporabnikih z identifikatorji 0, 2 in 3 se kaže visoka učinkovitost prvih dveh metod aktivnega učenja. Prav tako je odstotek napačnih izbir tehnik aktivnega učenja majhen (12.67%, 16%, 8.33%). Na teh uporabnikih je algoritem UCB zaradi visokih vsot skupne nagrade največkrat tudi uporabil prvo metodo. Pri uporabniku z indeksom 3 pa se kaže nekoliko bolj enakomerna menjava prve in druge metode aktivnega učenja.
#
# * Čeprav je uporabnik z identifikatorjem 1 aplikacijo malo uporabljal (prispeval je le 14 vnosov), algoritem UCB vseeno ni naredil preveliko število napačnih izbir. Delež zgrešenih poskusov je namreč le 21.43%. Vseeno se tudi pri tem uporabniku izkažeta prvi dve metodi aktivnega učenja kot najboljši.
#
# * Uporabnik z identifikatorjem 4 je prispeval v prvem delu druge študije najmanj vnosov. Pri njem se tudi kaže največji delež napačnih izbir metod aktivnega strojnega učenja, ki znaša 40%. Vzrok za tako velik odstotek napačnih odločitev je ta, da algoritem UCB ni uspel konvergirati k najboljši metodi, saj uporabnik aplikacije ni veliko uporabljal. Vseeno sta se prvi dve metodi aktivnega učenja pri tem uporabniku izkazali nekoliko boljši kot drugi dve.
#
# * Nobena izmed metod aktivnega učenja ne odstopa pri uporabikih z identifikatorji 5 in 6. Posledično tudi algoritem UCB ni uspel pri njima določiti, katera metoda aktivnega učenja je najboljša. Čeprav je uporabnik z identifikatorjem 5 prispeval velik delež vnosov algoritem UCB na tem uporabniku ni deloval dobro. Skupna nagrada je celo negativna prav tako pa je število posameznih poskusov enakomerno porazdeljeno. Omenjena dva uporabnika bomo v nadaljevanju analize podrobneje analizirali.

# %% [markdown]
# | Uporabnik | Skupna nagrada posameznih metod | Število posameznih poskusov | Skupno števlo poskusov | Skupna nagrada | Število zgrešenih poskusov | Delež zgrešenih poskusov |
# |-----------|---------------------------------|-----------------------------|------------------------|----------------|----------------------------|--------------------------|
# | 0         | [31.72, 5.47, -3.40, -1.98]     | [50, 16, 2, 3]              | 71                     | 31.82          | 9                          | 12.67%                   |
# | 1         | [3.79, 4.08, -1.90, -1.93]      | [5, 6, 1, 2]                | 14                     | 4.04           | 3                          | 21.43%                   |
# | 2         | [15.34, 2.07, -1.95, -1.75]     | [15, 6, 2, 2]               | 25                     | 13.71          | 4                          | 16.00%                   |
# | 3         | [26.04, 12.60, -1.41, -1.85]    | [34, 21, 3, 2]              | 60                     | 35.38          | 5                          | 8.33%                    |
# | 4         | [1.54, 2.73, -0.01, -0.01]      | [2,2,4,2]                   | 10                     | 4.25           | 4                          | 40%                      |
# | 5         | [-0.02, 2.50, -0.50, -2.50]     | [17, 23, 15, 11]            | 66                     | -0.27          | 8                          | 12.12%                   |
# | 6         | [1.38, 0.39, -1.71, -2.25]      | [6,5,3,2]                   | 16                     | -2.20          | 5                          | 31.25%                   |

# %% [markdown]
# # Graf kumulativne nagrade skozi čas
#
# Radi bi preverili spreminjanje vsote nagrad skozi čas. Na ordinatni osi bo torej vsota prejete nagrade do n-tega poskusa. Zaradi preglednosti bomo narisali dva različna grafa, saj so udeleženci raziskave prispevali različno število vnosov. Posledično bi graf funkcije bil manj pregleden za tiste uporabnike, ki so aplikacijo manj uporabljali.
#
# Iz spodnjih grafov, vidimo, da je vsota nagrad skozi čas naraščala pri večini uporabnikov.
#
# Uporabnika z identifikatorji 5 (zelena črta na prvem grafu) in 6 (rdeča črta na drugem grafu) tako kot pri zgornji tabeli odstopata od ostalih uporabnikov.

# %%
def plot_rewards(userIDs, ax):
    for userID in userIDs:
        rewards = bandit_df.loc[( bandit_df["uID"] == userID )]["total_reward"].tolist()
        trials = bandit_df.loc[( bandit_df["uID"] == userID )]["trial"].tolist()
        ax.legend(userIDs)
        ax.plot(trials, rewards, label=userID)

# %%
fig = plt.figure(figsize=(16, 5))
ax1 = fig.add_subplot(1,2,1)
plot_rewards(["user0", "user3", "user5"], ax1)
ax2 = fig.add_subplot(1,2,2)
plot_rewards(["user1", "user2", "user4", "user6"], ax2)

# %% [markdown]
# # Analiza parametrov konteksta
#
# V okviru druge študije smo uporabili fizično aktivnost in svetlost okolice za napovedovanje parametrov prikaza novic. Omenjena dva parametra konteksta sta se namreč v prvi raziskavi izkazala kot najbolj pomembna izmed preostalih.
#
# Glede na to, da se druga raziskava deli na dva dela si bomo pogledali porazedlitev fizične aktivnosti in svetlosti okolice za posameznika v prvem in drugem delu študije. S pomočjo metrike Jensen–Shannon, ki temelji na Kullback-Leiber divergenci, si bomo pogledali, kolikšna je razlika med porazdelitvijo podatkov.

# %% [markdown]
# # Analiza fizične aktivnosti uporabnika

# %% [markdown]
# # Analiza odgovorov na vprašalnik
#
# Omenili smo, da bomo poiskali razlog, zakaj algoritem UCB pri zadnjih dveh uporabnikih ni deloval dovolj dobro.
#
# V nadaljevanju si bomo zato najprej pogledali, ali se morda odgovori pri šestem in sedmem uporabniku, na zastavljen vprašalnik, med seboj močno razlikujejo od ostalih uporabnikov.

# %%
def draw_pie(labels, sizes, ax, userID):
    ax.set_title(userID)
    ax.pie(sizes, labels=labels,
            autopct='%1.1f%%', shadow=True, startangle=140)
    ax.axis('equal')

# %%
def analyze_user_y_n():
    fig = None
    for i in range(0,7):
        
        if i%3 == 0:
            fig = plt.figure(figsize=(15, 5))

        ax = fig.add_subplot(1,3,i%3 + 1)
        userYes = len(pred_df.loc[ (pred_df["uID"] == "user"+str(i)) & (pred_df["feedback"]  == 'Y')])
        userNo = len(pred_df.loc[ (pred_df["uID"] == "user"+str(i)) & (pred_df["feedback"]  == 'N')])
        print("User", i, "Yes = ",userYes, "No = ", userNo)
        draw_pie(["yes", "no"], [userYes, userNo], ax, "user"+str(i))

# %%
analyze_user_y_n()
# Out:
# User 0 Yes =  46 No =  25
# User 1 Yes =  7 No =  7
# User 2 Yes =  8 No =  17
# User 3 Yes =  34 No =  26
# User 4 Yes =  7 No =  3
# User 5 Yes =  64 No =  2
# User 6 Yes =  13 No =  3

# %% [markdown]
# Zgornji tortni diagrami so prikaz uporabnikovih odgovorov v prvem delu študije. Udeleženci raziskave so imeli na voljo le dva odgovora "Da" in "Ne".
#
# Pri petem in šestem tortnem diagramu, ki prikazuje odgovore najbolj kritičnih uporabnikov v prvem delu študije (algoritem UCB je imel nagrado negativno) opazimo razlike v odgovorih v primerjavi z ostalimi.
#
# Deleža njunih odgovorov z "Da" znašata 81.2% in kar 97%. To pomeni, da je obema uporabnikoma, katerikoli prikaz novic v vsakem trenutki, bil všeč. Posledično je to lahko, razlog za slabšo učinkovitost algoritma UCB, saj sta oba uporabnika z vsemi uporabniškimi vmesniki zadovoljna. Peti uporabnik, je tudi prispeval veliko manj vnosov (16 vnosov) kot šesti (66 vnosov). Razlog za slabšo učinkovitost algoritma UCB pri petem uporabniku je lahko tudi premajhna količina novih podatkov.

# %% [markdown]
# # Primerjava učinkovitosti splošnega in personaliziranega napovednega modela
#
# Omenili smo, da bomo v drugem delu druge študije primerjali učinkovitost splošnega in personaliziranega napovednega modela. Spodnja tabela število napovedi omenjenih modelov in delež napovedi s katerimi je bil uporabnik zadovoljen.
#
# Iz spodnje tabele opazimo, da personalizacija napovednih modelov, poveča uporabnikovo zadovoljstvo pri vseh uporabnikih razen pri uporabniku z identifikatorjem 4. Razlog za to je, da je ta v prvem delu študije prispeval najmanj podatkov (zbranih je bilo samo 10 vnosov). Prav tako pa je število napovedi splošnega modela pri tem uporabniku veliko manjša od števila napovedi personaliziranega. Razlog za to je, da je pojavitev vprašalnika odvisna od števila kolikrat uporabnik vstopi na zaslon za prikaz novic.
#
# Prav tako je zadnji uporabnik prispeval v drugem delu študije malo vnosov (skupno 13), a se vseeno kaže višja učinkovitost delovanja personaliziranega napovednega modela

# %% [markdown]
# | Uporabnik | Št. napovedi splošnega modela | Št. napovedi personaliziranega modela | Točnost splošnega modela | Točnost personaliziranega modela |
# |-----------|-------------------------------|---------------------------------------|--------------------------|----------------------------------|
# | 0         | 32                            | 45                                    | 47%                      | 71%                              |
# | 1         | 9                             | 13                                    | 44%                      | 69%                              |
# | 2         | 49                            | 31                                    | 51%                      | 61%                              |
# | 3         | 15                            | 26                                    | 47%                      | 73%                              |
# | 4         | 3                             | 11                                    | 66%                      | 36%                              |
# | 5         | 31                            | 48                                    | 68%                      | 98%                              |
# | 6         | 6                             | 7                                     | 33%                      | 71%                              |

# %% [markdown]
# # Primerjava napovedi personaliziranega in splošnega napovednega modela na posamezniku

# %% [markdown]
# V nadaljevanju si bomo pogledali, kako se razlikujejo napovedi personaliziranega in splošnega napovednega modela. Glede na to, da je večina aplikacijo uporabljala, ko je bila vrednost fizične aktivnosti enaka STILL (kar prikazuje spodnji tortni diagram), se bomo osredotočili na razlike napovedih modelov z enako vrednostjo svetlosti okolice. Njo bomo razdelili v dve skupini.
#
# V prvi se bodo nahajale vrednosti na intervalu [0 lux,100 lux], v drugi pa bodo vrednosti, kjer je svetlost okolice večja od 100 lux. Mejo za delitev 100 lux smo izbrali, ker v [tabeli](https://en.wikipedia.org/wiki/Lux) lahko razberemo, da vrednosti večje od 100 lux predstavljajo odprte prostore, medtem ko vrednosti manjše od 100 lux zaprte.
#
# Ko je svetlost okolice, večja od 100 lux lahko pričakujemo, da uporabniki hodijo, se voziijo ali pa sedijo na odprtem. Kot smo omenili vrednosti svetlosti okolice, ki so manjše od 100 lux predstavljajo zaprte prostore. Zaradi tega lahko sklepamo da posamezniki takrat večinoma sedijo oz. mirujejo.
#
# Pri vsakem uporabniku bo najprej predstavljena tabela učinkovitosti in porazdelitve napovedi personaliziranega ter splošnega napovednega modela. Ta bo sestavljena iz sledečih stolopcev:
#
# 1. Nivo svetlosti okolice - ta pove interval vrednost svetlosti okolice v luxih za katerega nas zanima razlika med modeloma
# 2. Točnost napovednih modelov - predstavlja vektor, ki pove deleže pravilnih napovedi posameznih napovednih modelov. Prva vrednost predstavlja delež pravilnih napovedi personaliziranga napovednega modela. Druga vrednost pa pove točnost splošnega napovednega modela.
# 3. Porazdelitev spremenljivke layout - spremenljivka 'layout' lahko zavezma dve različni vrednosti, in sicer 'largeCards' in 'xLargeCards'. Porazdelitev spremenljivke 'layout' je predstavljena z dvema vektorjema. Oba vsebujeta po dve vrednosti. Prvi predstavlja porazdelitev napovedi personaliziranega napovednega modela , drugi pa porazdelitev napovedi splošnega modela. Vektorja sta sestavljena v sledečem formatu: [št. napovedi largeCards, št. napovedi xLargeCards]
# 4. Porazdelitev spremenljivke theme - spremenljivka 'theme' lahko zavzema dve različne vrednosti light-theme ali dark theme. Porazdelitev napovedi splošnega in personaliziranega napovednega modela bomo predstavili z dvema vektorjema. Prvi predstavlja porazdelitev spremenljivke 'theme' za personaliziran splošni model drugi pa za splošnega. Oba sta sestavljena iz formata: [št. napovedi light-theme, št. napovedi dark-theme]
# 5. Porazdelitev spremenljivke fontSize - spremenljivka 'fontSize' ima lahko dve vrednosti 'small-font' ali 'large-font'. Porazdelitev spremenljivke 'fontSize' bo predstavljena z dvema vektorjema v formatu [št. napovedi small-font, št. napovedi large-font]. Prvi vektor bo predstavljal porazdelitev spremenljivke 'fontSize' za personaliziran napvedni model drugi pa za splošnega.
#
# Za vsakega posameznika bomo predstavili tudi tabeli učinkovitosti napovedi posameznih parametrov prikaza novic ('layout', 'theme', 'fontSize'). Tabeli sta zgrajeni iz sledečih stolpcev:
#
# 1. Svetlost okolice - pove nivo svetlosti okolice za katerega opazujemo razlike napovedi med modeloma
# 2. Temu sledijo stolpci, ki povejo vektorje deležev pravilnih in nepravilnih napovedi obeh modelov. Prvi vektor predstavlja točnost personaliziranega napovednega model drugi pove točnost splošnega. Oba sta setstavljena iz sledečega formata [% napačnih napovedi - % pravilnih napovedi]. Prva vrednost vektorja torej pove delež napačnih napovedi modela, kar pomeni, da je uporabnik po napovedanem prikazu novic odgovoril z 'NE - prikaz novic mi ni všeč'. Druga vrednost predstavlja delež pravilnih napovedi. Ta torej zajema delež take napovedi, za katere je uporabnik odgovoril 'DA - prikaz novic mi je všeč'.

# %%
def draw_pie2(labels, sizes):
    plt.pie(sizes, labels=labels,
            autopct='%1.1f%%', shadow=True, startangle=140)
    plt.axis('equal')
    plt.show()
    
count_still = len(ph2_df.loc[(ph2_df["user_activity"] == "STILL")])
count_foot = len(ph2_df.loc[(ph2_df["user_activity"] == "ON_FOOT")])
count_vehicle = len(ph2_df.loc[(ph2_df["user_activity"] == "IN_VEHICLE")])
draw_pie2(["STILL", "ON_FOOT", "IN_VEHICLE"], [count_still, count_foot, count_vehicle])

# %%
def transform_b(b):
    if b <= 100:
        return "L1"
    return "L2"

def analyzeParameter(dfP, dfG, par_name, par_values):
    results_p = []
    results_g = []
    
    results_pp = []
    results_gg = []
    
    results_ppp = []
    results_ggg = []
    
    
    for par_value in par_values:
        p = len(dfP.loc[ dfP[par_name] == par_value ])
        pp_y = len(dfP.loc[ (dfP[par_name] == par_value) & (dfP["feedback"] == "Y") ])
        pp_n = p - pp_y
                   
        g = len(dfG.loc[ dfG[par_name] == par_value ])
        gg_y = len(dfG.loc[ (dfG[par_name] == par_value) & (dfG["feedback"] == "Y") ])
        gg_n = g - gg_y

        results_p.append(p)
        results_g.append(g)
        
        results_pp.append([pp_n, pp_y])
        results_ppp.append([ round(pp_n/ ((pp_n + pp_y) or 1),2), round(pp_y / ((pp_n + pp_y) or 1), 2)])
        
        results_gg.append([gg_n, gg_y])
        results_ggg.append([ round(gg_n/ ((gg_n + gg_y) or 1),2), round(gg_y / ((gg_n + gg_y) or 1), 2)])           
    
    print("Splosna porazdelitev podatkov napovedi:")
    print(par_name, results_p, results_g)
    print("==")
    print("p = ",results_pp)
    print("g = ",results_gg)
    print("pp = ", results_ppp)
    print("gg = ", results_ggg)
    print()
        
    
ph2_df["env_b2"] = ph2_df["env_b"].map(lambda brightness: transform_b(brightness))

def model_comparison(userID, df):
    
    for eb2 in ["L1", "L2"]:
        
        print("BrightnessLevel", eb2)
       
        # full dataframe personalized model
        full_df_p_m = df.loc[(df["algo"] == 0) & (df["uID"] == userID) & (df["env_b2"] == eb2)]
        # full dataframe generalized model
        full_df_g_m = df.loc[(df["algo"] == 1) & (df["uID"] == userID) & (df["env_b2"] == eb2)]
        
        # Splosen performance
        yes_p = len(full_df_p_m.loc[full_df_p_m["feedback"] == "Y"])
        yes_g = len(full_df_g_m.loc[full_df_g_m["feedback"] == "Y"])
        
        procent_yes_person = round(yes_p / (len(full_df_p_m) or 1), 2)
        procent_yes_general = round(yes_g / (len(full_df_g_m) or 1),2)
       
        
        print("Personaliziran: ", procent_yes_person, "Generaliziran: ", procent_yes_general)
        print("St. napovedi personaliziran: ", len(full_df_p_m), "St. Napovedi generaliziran", len(full_df_g_m))
        analyzeParameter(full_df_p_m, full_df_g_m, "layout", ["largeCards", "xLargeCards"])
        analyzeParameter(full_df_p_m, full_df_g_m, "theme", ["light-theme", "dark-theme"])
        analyzeParameter(full_df_p_m, full_df_g_m, "fontSize", ["small-font", "large-font"])

# %%
def draw_pie3(labels, sizes, ax, title):
    ax.set_title(title)
    ax.pie(sizes, labels=labels,
            autopct='%1.1f%%', shadow=True, startangle=140)
    ax.axis('equal')


def analyze_user_output_pref(userID, var_name, var_values):
    
    fig = plt.figure(figsize=(15,5))
    
    for i in range(0, len(var_values)):
        value = var_values[i]
        predtotal = pred_df.loc[ (pred_df["user_activity"] == "STILL") & 
                    (pred_df["uID"] == userID) &  
                    (pred_df[var_name] == value)]
        pred_total_y = len(predtotal.loc[predtotal["feedback"] == "Y"])
        pred_total_n = len(predtotal.loc[predtotal["feedback"] == "N"])
        ax = fig.add_subplot(1,2,i+1)
        draw_pie3(["Y", "N"], [pred_total_y, pred_total_n], ax, value + " " +userID)

# %% [markdown]
# ### Analiza napovedi user0
#
# #### Analiza učnikovtosti in porazdelitve splošnega in personaliziranega napovednega modela
#
# Iz drugega stolpca lahko razberemo, da je personaliziran napovedni model dosegal boljše rezultate, ko je bila svetlost okolice manjša od 100. Točnost personaliziranega napovednega modela je znašala takrat 70%, medtem ko splošnega 56%. Prav tako je personaliziran napovedni model bil boljši od splošnega, ko se je uporabnik nahajal v prostorih, kjer je bila svetlost okolice večja od 100 lux. Takrat je točnost personaliziranega napovednega modela znašala 75%, splošnega pa 36%.
#
# Porazdelitvi napovedi za spremenljivko 'layout' v temnih prostorih sta si med seboj podobni. Oba modela takrat večkrat napovesta 'largeCards' kot 'xLargeCards'. V svetlejšem okolju se izkaže, da personaliziran napovedni model vedno napove izbiro 'largeCards' ([12,0]) za razliko od splošnega napovednega modela, ki večkrat napove 'xLargeCards' na izhodu ([4, 10])
#
# Vrednosti, ki predstavljajo porazdelitev spremenljivke 'theme' se med seboj zelo razlikujejo. Personaliziran napovedni model namreč bolj enakomerno menjava temo aplikacije v temnejših ([17,16]) kot tudi svetlejši okolici ([5,13]). Splošni napovedni model daje prednost temni temi aplikacije v temnejših prostorih ([5,13]) v svetlejših pa vedno napove, da bo uporabniku všeč svetla tema aplikacije (14,0).
#
# Pri spremenljivki 'fontSize' lahko opazimo, da personaliziran napovedni model bolj enakomerno menjava med veliko in majhno pisavo ([19,14]) kot splošni napovedni model ([14,14]). Pri čemer oba modela napovesta, da bo uporabniku takrat bolj všeč manjša pisava kot večja.
#
# V svetlejših prostorih lahko opazimo, da personaliziran napovedni model daje prednost veliki pisavi ([2,10]). Splošni napovedni model pisavo takrat, bolj enakomerno menjava ([9,15]).

# %% [markdown]
# | Nivo svetlosti okolice | Točnost napovednih modelov | Porazdelitev spremenljivke layout | Porazdelitev spremenljivke theme | Porazdelitev spremenljivke fontSize |
# |------------------------|----------------------------|-----------------------------------|----------------------------------|-------------------------------------|
# | [0, 100]               | [0.70, 0.56]               | [25, 8] [14, 4]                   | [17, 16] [5, 13]                 | [19, 14] [14, 4]                    |
# | (100, +Inf]            | [0.75, 0.36]               | [12, 0] [4, 10]                    | [8, 4] [14, 0]                   | [2, 10] [9, 5]                      |

# %% [markdown]
# ##### Točnost napovedi spremenljivke 'layout'
#
# Iz spodnje tabele lahko razberemo, da je personaliziran napovedni model, bolje napovedoval vrednost spremenljivke 'largeCards' v temnejših prostorih. Delež pravilnih odgovorov personaliziranega napovednega model znaša 0.88, splošnega pa 0.64. Vrednost spremenljikve 'xLargeCards' sta oba modela slabo napovedovala, razlog za to je, da je ta uporabnik skoraj vedno imel raje 'largeCards' kot 'xLargeCards' na kar nakazuje spodnji tortni diagram, ki predstavlja deleže pozitivnih odgovorov podatkov prve študije tega uporabnika, ko je bil prikazan 'largeCards' in 'xLargeCards'. Uporabniku z identifikatorjem 0 skoraj v 85.7% primerih pogled xLargeCards ni bil všeč. To je tudi razlog, zakaj personaliziran model večinoma napoveduje vrednost 'largeCards' za parameter 'layout'.
#
#
# V svetlejših prostorih se izkaže, da splošni in personaliziran napovedni model dobro napovedujeta izbiro 'largeCards' spremenljivke layout. Deleža pravilnih napovedi znaša za personaliziran model 0.75 za splošnega pa 1. Od tod lahko razberemo, da splošni napovedni model, nikoli ni napačno napovedal spremenljivke 'largeCards'. Pri tem moramo upoštevati iz zgornje tabele, da jo je napovedal le štirikrat (vektor [4,10]).
#
# V splošnem se izkaže, da noben izmed modelov ni dobro napovedoval izbiro 'xLargeCards' za parameter 'layout'. Razlog za to je, da je temu uporabniku skoraj nikoli ni bil všeč pogled 'xLargeCards'.

# %% [markdown]
# | Nivo svetlosti okolice | Delež točnosti napovedi 'largeCards' | Delež točnosti napovedi 'xLargeCards' |
# |------------------------|--------------------------------------|---------------------------------------|
# | [0, 100]               | [0.12, 0.88] [0.36, 0.64]            | [0.88, 0.12] [0.75, 0.25]             |
# | [100, +Inf]            | [0.25, 0.75] [0.0, 1.0]              | [0.0, 0.0] [0.9, 0.1]                 |

# %%
analyze_user_output_pref("user0", "layout", ["largeCards", "xLargeCards"])

# %% [markdown]
# ##### Točnost napovedi spremenljivke 'theme'
#
# Iz spodnje teme lahko sklepamo, da personaliziran napovedni model vedno boljše napoveduje svetlo temo v temnejših okolicah. Vrednost 'light-theme' ustezno napove v kar 94%, prav tako jo vedno pravilno napove v svetlejših okolicah.
#
# Vrednost spremenljivke 'dark-theme' v temnešjih okolicah oba modela slabše napovedujeta. Deleža pravilnih napovedi pri obeh modelih je pod 50%. Razlog za to, lahko opazimo na spodnjih tortnih diagrabih. Iz njih razberemo, da je uporabnik v kar 80% primerih imel raje svetlo temo aplikacije.
#
# Od tod lahko tudi sklepamo tudi, da je prav to razlog za spremembo porazdelitve teme aplikacije. Splošni napovedni model je na začetku z 28% verjetnostjo napovedal svetlo temo aplikacije v temnem okolju za razliko od personaliziranega napovednega modela, ki je svetlejšo temo aplikacije v temnem okolju nastavil z verjetnostjo 51%.

# %%
analyze_user_output_pref("user0", "theme", ["light-theme", "dark-theme"])

# %% [markdown]
# | Nivo svetlosti okolice | Delež točnosti napovedi 'light-theme' | Delež točnosti napovedi 'dark-theme' |
# |------------------------|--------------------------------------|-------------------------------------|
# | [0, 100]               | [0.06, 0.94] [0.2, 0.8]              | [0.56, 0.44] [0.54, 0.46]           |
# | [100, +Inf]            | [0.0, 1.0] [0.64, 0.36]              | [0.75, 0.25] [0.0, 0.0]             |

# %% [markdown]
# ##### Točnost napovedi spremenljivke 'fontSize'
#
# Pri spremenljivki, ki označuje velikost pisave lahko opazimo, da personaliziran in splošni napovedni model zelo dobro napovedujeta veliko pisavo v temnejšem okolju. Njuna natančnost napovedi velike pisave znaša takrat kar 100%.
#
# V svetlejši kot tudi temnejši okolici oba modela slabo napovedujeta vrednost za velikost pisave. Njuni natančnosti napovedi znašajo 43% in 11%.
#
# Razloga za to ne moremo iskati v tortnih diagramih, saj se izkaže, da ta uporabnik za nobeno izmed pisav, ni vedno dajal pozitivnih ali negativnih odgovorov. Lahko se izkaže, da je razlog za slabše napvedi velikosti pisav slaba izbira teme aplikacije ali pogleda.

# %%
analyze_user_output_pref("user0", "fontSize", ["small-font", "large-font"])

# %% [markdown]
# | Nivo svetlosti okolice | Delež točnosti napovedi 'small-font' | Delež točnosti napovedi 'large-font' |
# |------------------------|------------------------------------|------------------------------------|
# | [0, 100]               | [0.53, 0.47] [0.57, 0.43]          | [0.0, 1.0] [0.0, 1.0]              |
# | [100, +Inf]            | [1.0, 0.0] [0.89, 0.11]            | [0.1, 0.9] [0.2, 0.8]              |

# %%
# rezultati so pridobljeni s spodnjim klicem funkcije, zaradi preglednosti, smo rezultate povezli v zgornjih
# tabelah
# model_comparison("user0", ph2_df)

# %%
# Zelo malo podatkov za L4, analizo bomo spustili, lahko analiziramo L1
# Personaliziran:  0.6923076923076923 Generaliziran:  0.3333333333333333 =>      p > g

# Layout se nagiba na largeCards pri splosnem modelu pa perfect balance [10, 3] [3, 3]
# personaliziran je largeCard kar 9x pravilno napovedal xLargeCards pa 3x napacno

# tema: [5, 8] [2, 4] => vredu balanciran pri obeh
# light temo velikokrat narobe [4,1] medtem ko dark temo vedno pravilno [0,8]

# fontSize  [6, 7] [0, 6] => personaliziran veliko bolj balanciran medtem k splosen vedno veliko pisavo
# manso pisavo personaliziran model dobro napoveduje 5x zadane 1x zgresi [1-5], veliko pisavo nekoliko slabse
# se vedno ima [3,4] vec na y
# glede na to da splosen model nikoli ne napove majhne pisave je posledicno [0,0]
# veliko pisavo pa ko napove jo veckrat zgresi [4,2]
model_comparison("user1", ph2_df)
# Out:
# BrightnessLevel L1
# Personaliziran:  0.6923076923076923 Generaliziran:  0.3333333333333333
# St. napovedi personaliziran:  13 St. Napovedi generaliziran 6
# Splosna porazdelitev podatkov napovedi:
# layout [10, 3] [3, 3]
# ==
# p =  [[1, 9], [3, 0]]
# g =  [[2, 1], [2, 1]]
#
# Splosna porazdelitev podatkov napovedi:
# theme [5, 8] [2, 4]
# ==
# p =  [[4, 1], [0, 8]]
# g =  [[2, 0], [2, 2]]
#
# Splosna porazdelitev podatkov napovedi:
# fontSize [6, 7] [0, 6]
# ==
# p =  [[1, 5], [3, 4]]
# g =  [[0, 0], [4, 2]]
#
# BrightnessLevel L4
# Personaliziran:  0 Generaliziran:  0.6666666666666666
# St. napovedi personaliziran:  0 St. Napovedi generaliziran 3
# Splosna porazdelitev podatkov napovedi:
# layout [0, 0] [1, 2]
# ==
# p =  [[0, 0], [0, 0]]
# g =  [[1, 0], [0, 2]]
#
# Splosna porazdelitev podatkov napovedi:
# theme [0, 0] [3, 0]
# ==
# p =  [[0, 0], [0, 0]]
# g =  [[1, 2], [0, 0]]
#
# Splosna porazdelitev podatkov napovedi:
# fontSize [0, 0] [0, 3]
# ==
# p =  [[0, 0], [0, 0]]
# g =  [[0, 0], [1, 2]]

# %%
# L4 SPUSTIMO 
# Personaliziran:  0.6129032258064516 Generaliziran:  0.5102040816326531  => p >> g
# oba napovedujeta [25, 6] [49, 0] vecinsko largeCards
# personaliziran model ko naredi napoved largeCards naredi veliko manj napak od splosneka [10,15] [24,25]
# splosen zgresi kar 24 napovedi od 25
# ko napove xLargeCards pa ima razmerje zadetkov personaliziran model [2,4]

# tema: [22, 9] [29, 20] => splosen model veliko bolj balanciran, personaliziran daje light themo
# ligh temo personaliziran veliko bolje napoveduje [7,15] [15,14], dark temo pa velikokrat oba zgresita [5,4] 
# [9,11]
# fontSize [9, 22] [26, 23] => splosni napovedni model veliko bolj balansirano, personaliziran daje prednost na
# veliko pisavo.
# oba imata velik delež napak manse pisave [5,4] [15,11] veliko pisavo personaliziran model nekoliko boljše
# napovedujne [7,15][9,14]
model_comparison("user2", ph2_df)
# Out:
# BrightnessLevel L1
# Personaliziran:  0.6129032258064516 Generaliziran:  0.5102040816326531
# St. napovedi personaliziran:  31 St. Napovedi generaliziran 49
# Splosna porazdelitev podatkov napovedi:
# layout [25, 6] [49, 0]
# ==
# p =  [[10, 15], [2, 4]]
# g =  [[24, 25], [0, 0]]
#
# Splosna porazdelitev podatkov napovedi:
# theme [22, 9] [29, 20]
# ==
# p =  [[7, 15], [5, 4]]
# g =  [[15, 14], [9, 11]]
#
# Splosna porazdelitev podatkov napovedi:
# fontSize [9, 22] [26, 23]
# ==
# p =  [[5, 4], [7, 15]]
# g =  [[15, 11], [9, 14]]
#
# BrightnessLevel L4
# Personaliziran:  0 Generaliziran:  0
# St. napovedi personaliziran:  0 St. Napovedi generaliziran 0
# Splosna porazdelitev podatkov napovedi:
# layout [0, 0] [0, 0]
# ==
# p =  [[0, 0], [0, 0]]
# g =  [[0, 0], [0, 0]]
#
# Splosna porazdelitev podatkov napovedi:
# theme [0, 0] [0, 0]
# ==
# p =  [[0, 0], [0, 0]]
# g =  [[0, 0], [0, 0]]
#
# Splosna porazdelitev podatkov napovedi:
# fontSize [0, 0] [0, 0]
# ==
# p =  [[0, 0], [0, 0]]
# g =  [[0, 0], [0, 0]]

# %%
# Personaliziran:  0.8333333333333334 Generaliziran:  0.36363636363636365  => personaliziran >> generaliziran
# layout [12, 0] [9, 2] => oba dajaeta prednost largeCards layoutu
# personaliziran model napove largeCards zelo dobro [2,10] naredi namreč le dve napaki izmed 12 napovedi
# splosni napovedni model velikokrat napačno napove largeCards [5,4]

# theme [7, 5] [4, 7] => oba priblizno enako napovedujeta temo.
# personalizran light temo zadane kar 100% pravilno, dark temo pa velikokrat tudi napacno napove [2,3]
# generaliziran light temo slabse napoveduje, večkrat napove dark temo, posledično velikokrat zgreši in jo le 1x
# zadane [6,1]

# fontSize [7, 5] [6, 5] => oba uravnotezeno
# majno pisavo napove persinaliziran 2x napacno, medtem ko veliko 5x zadane.
# generaliziran model vsakic ko napove veliko pisavo, zgreši. veliko pisavo tudi nekolikokrat zadane

### L4 ###
## presenetljivo personalizran slabsi, verjetno ker je bilo personaliziranih napovedi 14, generaliziranih le 4

## layout [7, 7] [2, 2] balansirana [za general model premalo podatkov]
# personaliziran model, kar slabo napoveduje za oba [3,4] [2,5] generaliziran tudi

# theme [13, 1] [4, 0] => oba favorizirata light temo.
# personaliziran izbiro light teme večinoma pravilno napove [5,8], nikoli ne zgreši dark theme
# generaliziran light temo tudi večinoma dobro napoveduje [1,3]

# font size [3, 11] [1, 3] => oba se nekoliko bolj nagibata k veliki pisavi [za general model premalo podatkov]
# personaliziran model [3, 8] zelo dobro napoveduje veliko pisavo, nekoliko slabše manjš [2, 1]
# za generaliziranega premalo podatkov 
model_comparison("user3", ph2_df)
# Out:
# BrightnessLevel L1
# Personaliziran:  0.8333333333333334 Generaliziran:  0.36363636363636365
# St. napovedi personaliziran:  12 St. Napovedi generaliziran 11
# Splosna porazdelitev podatkov napovedi:
# layout [12, 0] [9, 2]
# ==
# p =  [[2, 10], [0, 0]]
# g =  [[5, 4], [2, 0]]
#
# Splosna porazdelitev podatkov napovedi:
# theme [7, 5] [4, 7]
# ==
# p =  [[0, 7], [2, 3]]
# g =  [[1, 3], [6, 1]]
#
# Splosna porazdelitev podatkov napovedi:
# fontSize [7, 5] [6, 5]
# ==
# p =  [[2, 5], [0, 5]]
# g =  [[6, 0], [1, 4]]
#
# BrightnessLevel L4
# Personaliziran:  0.6428571428571429 Generaliziran:  0.75
# St. napovedi personaliziran:  14 St. Napovedi generaliziran 4
# Splosna porazdelitev podatkov napovedi:
# layout [7, 7] [2, 2]
# ==
# p =  [[3, 4], [2, 5]]
# g =  [[1, 1], [0, 2]]
#
# Splosna porazdelitev podatkov napovedi:
# theme [13, 1] [4, 0]
# ==
# p =  [[5, 8], [0, 1]]
# g =  [[1, 3], [0, 0]]
#
# Splosna porazdelitev podatkov napovedi:
# fontSize [3, 11] [1, 3]
# ==
# p =  [[2, 1], [3, 8]]
# g =  [[0, 1], [1, 2]]

# %%
# user 5 je zelo pozitiven pri svojih ocenah
# Personaliziran:  1.0 Generaliziran:  0.6551724137931034
# layout [24, 7] [25, 4]  => oba largeCards 
# personaliziran izbire med layouti presenetljivo nikoli ne zgreši. Generaliziran pa kar 10x narobe
# napove izbiro largeCards

# tema [24, 7] [11, 18] =>  personaliziran light, globalen balansirano
# personalizran nikoli ne zgreši ne light ne dark teme. Generelaziran velikokrat zgreši light temo [10,11]
# [0,8]

# L4, generaliziran bolsi, ampak se not skrivata le dve napovedi => obravnavamo le personalizranega
# Layout personalizran largeCaredds nikoli ne zgresi [0,8] xLargeCards pa le 1x [1,9]

# [9, 8] => veliko vec lightTheme
# light vedno pravilno napove [0,9] [1,7] dark pa le 1x zgreši

# fontSize [7, 10]
# [0, 7], [1, 9] => small font ne zgreši largeFont le 1x
model_comparison("user5", ph2_df)
# Out:
# BrightnessLevel L1
# Personaliziran:  1.0 Generaliziran:  0.6551724137931034
# St. napovedi personaliziran:  31 St. Napovedi generaliziran 29
# Splosna porazdelitev podatkov napovedi:
# layout [24, 7] [25, 4]
# ==
# p =  [[0, 24], [0, 7]]
# g =  [[10, 15], [0, 4]]
#
# Splosna porazdelitev podatkov napovedi:
# theme [24, 7] [11, 18]
# ==
# p =  [[0, 24], [0, 7]]
# g =  [[4, 7], [6, 12]]
#
# Splosna porazdelitev podatkov napovedi:
# fontSize [7, 24] [21, 8]
# ==
# p =  [[0, 7], [0, 24]]
# g =  [[10, 11], [0, 8]]
#
# BrightnessLevel L4
# Personaliziran:  0.9411764705882353 Generaliziran:  1.0
# St. napovedi personaliziran:  17 St. Napovedi generaliziran 2
# Splosna porazdelitev podatkov napovedi:
# layout [7, 10] [0, 2]
# ==
# p =  [[0, 7], [1, 9]]
# g =  [[0, 0], [0, 2]]
#
# Splosna porazdelitev podatkov napovedi:
# theme [9, 8] [2, 0]
# ==
# p =  [[0, 9], [1, 7]]
# g =  [[0, 2], [0, 0]]
#
# Splosna porazdelitev podatkov napovedi:
# fontSize [7, 10] [2, 0]
# ==
# p =  [[0, 7], [1, 9]]
# g =  [[0, 2], [0, 0]]

# %%
# l4 spustimo 
# Personaliziran:  0.7142857142857143 Generaliziran:  0.2 => p >> g

# Layout [5, 2] [2, 3] balanced
# personalizran nikoli ne zgresi largeCardsa, generaliziranVedno
# personaliziran nikoli ne napove pravilno xLargeCards.

# tema: [2, 5] [3, 2] => nekoliko več dark tema
# personaliziran light ne fali, dark nekoliko večkrat
# generaliziran dost slabo in light in dark

# [3, 4] [0, 5] generalizran vedno largeFont
# persanaliziran nikoli ne zgreši velike pisave, za razliko od generaliziranega
# slabše napoveduje manjšo pisavo. 
model_comparison("user6", ph2_df)
# Out:
# BrightnessLevel L1
# Personaliziran:  0.7142857142857143 Generaliziran:  0.2
# St. napovedi personaliziran:  7 St. Napovedi generaliziran 5
# Splosna porazdelitev podatkov napovedi:
# layout [5, 2] [2, 3]
# ==
# p =  [[0, 5], [2, 0]]
# g =  [[2, 0], [2, 1]]
#
# Splosna porazdelitev podatkov napovedi:
# theme [2, 5] [3, 2]
# ==
# p =  [[0, 2], [2, 3]]
# g =  [[2, 1], [2, 0]]
#
# Splosna porazdelitev podatkov napovedi:
# fontSize [3, 4] [0, 5]
# ==
# p =  [[2, 1], [0, 4]]
# g =  [[0, 0], [4, 1]]
#
# BrightnessLevel L4
# Personaliziran:  0 Generaliziran:  1.0
# St. napovedi personaliziran:  0 St. Napovedi generaliziran 1
# Splosna porazdelitev podatkov napovedi:
# layout [0, 0] [1, 0]
# ==
# p =  [[0, 0], [0, 0]]
# g =  [[0, 1], [0, 0]]
#
# Splosna porazdelitev podatkov napovedi:
# theme [0, 0] [1, 0]
# ==
# p =  [[0, 0], [0, 0]]
# g =  [[0, 1], [0, 0]]
#
# Splosna porazdelitev podatkov napovedi:
# fontSize [0, 0] [0, 1]
# ==
# p =  [[0, 0], [0, 0]]
# g =  [[0, 0], [0, 1]]

# %%
## TODO: mogoče kako je user klikal posamezne metrike
## kaj je bilo generalizran pred
## kaj personalizran pio
